# %% [markdown]
# ##**Pandas**

# %% [markdown]
# ##**Importando la Base de Datos**

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'
pd.read_csv(url)
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1                       Casa;Polanco;2;0;1;100;24500.0;;
# 2      Conjunto Comercial/Sala;Santa Fe;0;4;0;150;182...
# 3      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 4          Departamento;Del Valle;1;0;0;48;2800.0;805.0;
# ...                                                  ...
# 25116  Cochera/Estacionamiento;Centro Histórico;0;0;0...
# 25117  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 25118  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 25119  Departamento;Lomas de Chapultepec;2;0;0;70;105...
# 25120  Conjunto Comercial/Sala;Centro Histórico;0;0;0...
#
# [25121 rows x 1 columns]

# %%
pd.read_csv(url, sep=';')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos = pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(10)
# Out:
#                              Tipo                 Colonia  Habitaciones  \
# 2307                 Departamento  San Miguel Chapultepec             3
# 6901                 Tienda/Salón                Coyoacán             0
# 15440                Departamento              San Rafael             1
# 8859      Conjunto Comercial/Sala        Centro Histórico             0
# 2973   Tienda en Centro Comercial                Santa Fe             0
# 14383     Galpón/Depósito/Almacén                Doctores             0
# 21130                Departamento    Bosques de las Lomas             4
# 11672                Departamento                Coyoacán             1
# 7071      Conjunto Comercial/Sala        Centro Histórico             0
# 9159      Conjunto Comercial/Sala              La Condesa             0
#
#        Garages  Suites  Area    Valor  Condominio  Impuesto
# 2307         1       1   110   6300.0      2922.5     346.5
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #**Exploración Inicial de los datos**

# %%
datos.sample(5)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 20547  Conjunto Comercial/Sala  Centro Histórico             0        0
# 19125  Conjunto Comercial/Sala  Centro Histórico             0        0
# 5012              Departamento          Coyoacán             3        1
# 4413          Casa de Vecindad         Moctezuma             1        0
# 6947   Conjunto Comercial/Sala              Roma             0        1
#
#        Suites  Area    Valor  Condominio  Impuesto
# 20547       0    35   2800.0      2222.5    3500.0
# 19125       0   470  26250.0     20499.5    7448.0
# 5012        2   110  21000.0      3010.0    1120.0
# 4413        0    50   2100.0         NaN       NaN
# 6947        0    48   9800.0      5600.0       NaN

# %%
datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones', 'Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %% [markdown]
# #**Demandas de ML**

# %% [markdown]
# ###¿Cuáles son los valores promedio de alquiler por tipo de propiedad?

# %%
datos.head(25)
# Out:
#                        Tipo               Colonia  Habitaciones  Garages  \
# 0                  Cocineta               Condesa             1        0
# 1                      Casa               Polanco             2        0
# 2   Conjunto Comercial/Sala              Santa Fe             0        4
# 3              Departamento      Centro Histórico             1        0
# 4              Departamento             Del Valle             1        0
# 5        Casa de Condominio              Santa Fe             5        4
# 6   Conjunto Comercial/Sala      Centro Histórico             0        3
# 7              Departamento      Centro Histórico             1        0
# 8              Departamento               Condesa             1        0
# 9                  Cocineta               Condesa             1        0
# 10             Departamento               Condesa             4        3
# 11        Edificio Completo                  Roma             0        0
# ...

# %%
datos['Valor'].mean()
# Out:
# np.float64(36885.05048392878)

# %%
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
datos.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
from matplotlib import colors
df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', figsize=(12,8),color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %%
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
inmuebles_comerciales= ['Conjunto Comercial/Sala',
       'Edificio Completo',
       'Tienda/Salón', 'Casa Comercial',
       'Terreno Estándar', 'Cochera/Estacionamiento',
       'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Hotel', 'Loteo/Condominio',
       'Industria']

# %%
datos.query('@inmuebles_comerciales in Tipo')
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 2      Conjunto Comercial/Sala          Santa Fe             0        4
# 6      Conjunto Comercial/Sala  Centro Histórico             0        3
# 11           Edificio Completo              Roma             0        0
# 24     Conjunto Comercial/Sala          Santa Fe             0        1
# 26     Conjunto Comercial/Sala  Centro Histórico             0        5
# ...                        ...               ...           ...      ...
# 25107  Conjunto Comercial/Sala          Santa Fe             0        1
# 25110  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25116  Cochera/Estacionamiento  Centro Histórico             0        0
# 25120  Conjunto Comercial/Sala  Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
datos.query('@inmuebles_comerciales not in Tipo')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = datos.query('@inmuebles_comerciales not in Tipo')
df.head(25)
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# 7            Departamento      Centro Histórico             1        0
# 8            Departamento               Condesa             1        0
# 9                Cocineta               Condesa             1        0
# 10           Departamento               Condesa             4        3
# 12  Departamento en Hotel                  Roma             3        1
# 13           Departamento              Santa Fe             2        1
# 14           Departamento              Narvarte             2        1
# ...

# %%
df_tipo_precio = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh', figsize=(12,8),color='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# ###¿Cuál es el porcentaje de cada tipo de propiedad en nuestra base de datos?

# %%
df.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Departamento', 'Casa de Condominio',
#        'Departamento en Hotel', 'Casa de Vecindad', 'Loft', 'Rancho',
#        'Posada/Chalé', 'Estudio'], dtype=object)

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Departamento             14764
# Cocineta                   726
# Casa de Condominio         610
# Casa                       545
# Departamento en Hotel      455
# Casa de Vecindad           158
# Loft                        38
# Rancho                       8
# Estudio                      4
# Posada/Chalé                 1
# Name: count, dtype: int64

# %%
df.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento             0.852967
# Cocineta                 0.041943
# Casa de Condominio       0.035242
# Casa                     0.031487
# Departamento en Hotel    0.026287
# Casa de Vecindad         0.009128
# Loft                     0.002195
# Rancho                   0.000462
# Estudio                  0.000231
# Posada/Chalé             0.000058
# Name: proportion, dtype: float64

# %%
porcentaje_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind= 'bar', figsize=(12,8), color='green', xlabel='Tipos', ylabel='Porcentajes')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentajes'>

# %%
df.query('Tipo == "Departamento"')
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 7      Departamento      Centro Histórico             1        0       0
# 8      Departamento               Condesa             1        0       1
# 10     Departamento               Condesa             4        3       1
# ...             ...                   ...           ...      ...     ...
# 25111  Departamento  Lomas de Chapultepec             3        0       1
# 25113  Departamento              Coyoacán             3        1       2
# 25114  Departamento              Narvarte             1        0       0
# 25118  Departamento               Mixcoac             2        1       0
# 25119  Departamento  Lomas de Chapultepec             2        0       0
#
#        Area    Valor  Condominio  Impuesto
# 3        15   2800.0      1365.0      70.0
# ...

# %%
df = df.query('Tipo == "Departamento"')
df.head(2)
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
#
#     Valor  Condominio  Impuesto
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       NaN

# %%
porcentaje_tipo = df.Tipo.value_counts(normalize=True).to_frame()
porcentaje_tipo.plot(kind= 'bar', figsize=(12,8), color='green', xlabel='Tipos', ylabel='Porcentajes')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentajes'>

# %%
promedio_habitaciones_departamento = df[df["Tipo"] == "Departamento"]['Habitaciones'].mean()
promedio_habitaciones_departamento
# Out:
# np.float64(2.5041994039555675)

# %%
colonias_unicas = df["Colonia"].nunique()
colonias_unicas
# Out:
# 87

# %%
promedio_alquiler = df.groupby("Colonia")["Valor"].mean().sort_values(ascending=False)
promedio_alquiler
# Out:
# Colonia
# Los Alpes                    58707.173913
# Xochimilco                   36925.000000
# Bosques de Aragón            32621.289474
# Coyoacán                     32186.409021
# Lomas de Chapultepec         30081.735272
#                                  ...
# Santa Marta Acatitla          2302.391304
# Las Aguilas                   2100.000000
# Santa María Aztahuacán        2030.000000
# San Mateo                     1750.000000
# Potrero de San Bernardino     1190.000000
# Name: Valor, Length: 87, dtype: float64

# %%
promedio_alquiler = df.groupby("Colonia")["Valor"].mean().sort_values().head(5).to_frame()
promedio_alquiler.plot(kind='barh',figsize=(12,8),color='purple', xlabel='Colonia', ylabel='Promedio de Alquiler',title='Las 5 Colonias con alquiler más alto')
# Out:
# <Axes: title={'center': 'Las 5 Colonias con alquiler más alto'}, xlabel='Colonia', ylabel='Promedio de Alquiler'>

# %% [markdown]
# ###**Valores Nulos**

# %%
df.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor              7
# Condominio      1155
# Impuesto        4645
# dtype: int64

# %%
df.fillna(0)
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1                    Casa               Polanco             2        0
# 3            Departamento      Centro Histórico             1        0
# 4            Departamento             Del Valle             1        0
# 5      Casa de Condominio              Santa Fe             5        4
# ...                   ...                   ...           ...      ...
# 25114        Departamento              Narvarte             1        0
# 25115  Casa de Condominio              Santa Fe             5        3
# 25117            Cocineta      Centro Histórico             0        0
# 25118        Departamento               Mixcoac             2        1
# 25119        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df = df.fillna(0)
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %% [markdown]
# ##**Remover Datos Inconsistentes**

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
#                      Tipo                 Colonia  Habitaciones  Garages  \
# 1                    Casa                 Polanco             2        0
# 5      Casa de Condominio                Santa Fe             5        4
# 7            Departamento        Centro Histórico             1        0
# 49           Departamento                Santa Fe             2        1
# 74           Departamento  Ciudad de los Deportes             2        0
# ...                   ...                     ...           ...      ...
# 25010    Casa de Vecindad                Doctores             3        0
# 25014        Departamento           Culhuacán CTM             3        0
# 25053    Casa de Vecindad    Santa Marta Acatitla             2        0
# 25086                Casa               Zacatenco             2        1
# 25099                Casa        Centro Histórico             5        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([    1,     5,     7,    49,    74,    78,    96,   116,   136,   154,
#        ...
#        24866, 24867, 24868, 24892, 24899, 25010, 25014, 25053, 25086, 25099],
#       dtype='int64', length=1162)

# %%
df_remover = df.query('Valor == 0 | Condominio == 0').index

# %%
df.drop(df_remover, axis=0, inplace=True)

# %%
df.query('Valor == 0 | Condominio == 0').index
# Out:
# Index([], dtype='int64')

# %%
df.head()
# Out:
#            Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 0      Cocineta           Condesa             1        0       0    40
# 3  Departamento  Centro Histórico             1        0       0    15
# 4  Departamento         Del Valle             1        0       0    48
# 8  Departamento           Condesa             1        0       1    40
# 9      Cocineta           Condesa             1        0       0    27
#
#     Valor  Condominio  Impuesto
# 0  5950.0      1750.0     210.0
# 3  2800.0      1365.0      70.0
# 4  2800.0       805.0       0.0
# 8  7000.0      1963.5     175.0
# 9  6300.0      1753.5       0.0

# %% [markdown]
# ##**Creando Filtos**

# %% [markdown]
# ##**Apartamentos que tienen 1 dormitorio y un alquiler menor a MXN 4200.**
#
# ##**Apartamentos que tienen al menos 2 dormitorios, un alquiler menor a MXN 10500 y una superficie mayor a 70 m².**

# %%
seleccion = df['Habitaciones']==1

# %%
type(seleccion)
# Out:
# pandas.core.series.Series

# %%
df[seleccion]
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 0          Cocineta               Condesa             1        0       0
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 8      Departamento               Condesa             1        0       1
# 9          Cocineta               Condesa             1        0       0
# ...             ...                   ...           ...      ...     ...
# 25092  Departamento              Santa Fe             1        1       0
# 25100  Departamento  Lomas de Chapultepec             1        1       1
# 25103  Departamento               Condesa             1        0       0
# 25109      Cocineta               Condesa             1        0       0
# 25114  Departamento              Narvarte             1        0       0
#
#        Area    Valor  Condominio  Impuesto
# 0        40   5950.0      1750.0     210.0
# ...

# %%
seleccion2 = df['Valor'] < 4200
df[seleccion2]
# Out:
#                Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3      Departamento  Centro Histórico             1        0       0    15
# 4      Departamento         Del Valle             1        0       0    48
# 19     Departamento          Narvarte             1        0       0    48
# 37     Departamento  Centro Histórico             1        0       0    27
# 61     Departamento  Centro Histórico             1        1       0    37
# ...             ...               ...           ...      ...     ...   ...
# 25051  Departamento         Nativitas             2        1       0    62
# 25065  Departamento         Nativitas             2        1       0    50
# 25095  Departamento    Lindavista Sur             2        0       0    63
# 25114  Departamento          Narvarte             1        0       0    28
# 25117      Cocineta  Centro Histórico             0        0       0    27
#
#         Valor  Condominio  Impuesto
# ...

# %%
df[seleccion2].max()
# Out:
# Tipo                      Loft
# Colonia         Álvaro Obregón
# Habitaciones                 3
# Garages                      2
# Suites                       2
# Area                       200
# Valor                   4165.0
# Condominio            152575.5
# Impuesto                6699.0
# dtype: object

# %%
filtro1 = (seleccion) & (seleccion2)
df[filtro1]
# Out:
#                Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3      Departamento  Centro Histórico             1        0       0    15
# 4      Departamento         Del Valle             1        0       0    48
# 19     Departamento          Narvarte             1        0       0    48
# 37     Departamento  Centro Histórico             1        0       0    27
# 61     Departamento  Centro Histórico             1        1       0    37
# ...             ...               ...           ...      ...     ...   ...
# 24880  Departamento        La Condesa             1        0       0    46
# 24943  Departamento              Roma             1        0       0    21
# 24981      Cocineta        La Condesa             1        0       0    10
# 25039      Cocineta  Centro Histórico             1        0       0    24
# 25114  Departamento          Narvarte             1        0       0    28
#
#         Valor  Condominio  Impuesto
# ...

# %%
df1 = df[filtro1]

# %%
filtro2 = (df['Habitaciones'] >= 2) & (df['Valor'] <10500) & (df['Area'] > 70)
df[filtro2]
# Out:
#                         Tipo   Colonia  Habitaciones  Garages  Suites  Area  \
# 14              Departamento  Narvarte             2        1       0   110
# 16              Departamento  Narvarte             2        1       0    78
# 21              Departamento      Roma             2        1       0    76
# 33              Departamento  Santa Fe             3        1       1    72
# 58              Departamento  Santa Fe             3        2       1   104
# ...                      ...       ...           ...      ...     ...   ...
# 25031  Departamento en Hotel  Santa Fe             2        1       2    77
# 25062           Departamento  Santa Fe             2        1       1    72
# 25063           Departamento  Narvarte             3        1       0    75
# 25105           Departamento  Santa Fe             2        1       1    85
# 25106           Departamento  Santa Fe             3        2       0    98
#
#         Valor  Condominio  Impuesto
# ...

# %%
df2 = df[filtro2]

# %% [markdown]
# ###**Guardando los archivos**

# %%
df.to_csv('inmueble_ml.cvs')

# %%
pd.read_csv('inmueble_ml.cvs')
# Out:
#        Unnamed: 0                Tipo               Colonia  Habitaciones  \
# 0               0            Cocineta               Condesa             1
# 1               3        Departamento      Centro Histórico             1
# 2               4        Departamento             Del Valle             1
# 3               8        Departamento               Condesa             1
# 4               9            Cocineta               Condesa             1
# ...           ...                 ...                   ...           ...
# 16142       25114        Departamento              Narvarte             1
# 16143       25115  Casa de Condominio              Santa Fe             5
# 16144       25117            Cocineta      Centro Histórico             0
# 16145       25118        Departamento               Mixcoac             2
# 16146       25119        Departamento  Lomas de Chapultepec             2
#
#        Garages  Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
df.to_csv('inmueble_ml.cvs', index=False)

# %%
pd.read_csv('inmueble_ml.cvs')
# Out:
#                      Tipo               Colonia  Habitaciones  Garages  \
# 0                Cocineta               Condesa             1        0
# 1            Departamento      Centro Histórico             1        0
# 2            Departamento             Del Valle             1        0
# 3            Departamento               Condesa             1        0
# 4                Cocineta               Condesa             1        0
# ...                   ...                   ...           ...      ...
# 16142        Departamento              Narvarte             1        0
# 16143  Casa de Condominio              Santa Fe             5        3
# 16144            Cocineta      Centro Histórico             0        0
# 16145        Departamento               Mixcoac             2        1
# 16146        Departamento  Lomas de Chapultepec             2        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 0           0    40   5950.0      1750.0     210.0
# ...

# %%
df.to_csv('inmueble_ml.cvs', index=False, sep=';')

# %%
pd.read_csv('inmueble_ml.cvs')
# Out:
#       Tipo;Colonia;Habitaciones;Garages;Suites;Area;Valor;Condominio;Impuesto
# 0          Cocineta;Condesa;1;0;0;40;5950.0;1750.0;210.0
# 1      Departamento;Centro Histórico;1;0;0;15;2800.0;...
# 2       Departamento;Del Valle;1;0;0;48;2800.0;805.0;0.0
# 3      Departamento;Condesa;1;0;1;40;7000.0;1963.5;175.0
# 4            Cocineta;Condesa;1;0;0;27;6300.0;1753.5;0.0
# ...                                                  ...
# 16142  Departamento;Narvarte;1;0;0;28;3500.0;1260.0;87.5
# 16143  Casa de Condominio;Santa Fe;5;3;4;450;52500.0;...
# 16144  Cocineta;Centro Histórico;0;0;0;27;2800.0;1225...
# 16145  Departamento;Mixcoac;2;1;0;48;4900.0;1781.5;129.5
# 16146  Departamento;Lomas de Chapultepec;2;0;0;70;105...
#
# [16147 rows x 1 columns]

# %%
df1.to_csv('inmueble_ml_filtro1.cvs', index=False, sep=';')
df2.to_csv('inmueble_ml_filtro2.cvs', index=False, sep=';')

# %% [markdown]
# ## **Demandas de Dev**

# %% [markdown]
# ### **Crear Columnas numericas-**

# %% [markdown]
# #### **valor_mensual: Esta columna debe contener los gastos mensuales de cada propiedad, incluyendo el alquiler y el condominio.**

# %%
datos = pd.read_csv(url, sep=';')
datos.shape
# Out:
# (25121, 9)

# %%
datos['Valor_mensual']= datos['Valor']+ datos['Condominio']
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %% [markdown]
# ####**valor_anual: Esta columna debe contener los gastos anuales por propiedad, es decir, el Impuesto más 12 meses de alquiler y condominio.**

# %%
datos['Valor_anual'] = datos['Valor_mensual'] * 12 + datos['Impuesto']
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 25116       0   755  49000.0         NaN       NaN            NaN          NaN
# 25117       0    27   2800.0      1225.0      87.5         4025.0      48387.5
# 25118       0    48   4900.0      1781.5     129.5         6681.5      80307.5
# 25119       0    70  10500.0      2660.0       NaN        13160.0          NaN
# 25120       0   250  22750.0     14721.0    3881.5        37471.0     453533.5

# %% [markdown]
# ###**Crear Columnas Categorícas**

# %% [markdown]
# ####Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %% [markdown]
# ####Descripcion: Esta columna debe contener un resumen de la información clave de las propiedades que se mostrarán en el sitio web: tipo de propiedad, barrio, cantidad de habitaciones y plazas de estacionamiento.

# %%
datos['Descripcion'] = datos['Tipo'] + ' en la colonia '+ datos['Colonia'] + \
                      'con ' + datos['Habitaciones'].astype(str) + 'cuartos y '+ \
                      datos['Garages'].astype(str)+ 'plazas de estacionamiento'
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                           Descrpcion  \
# ...

# %%
datos.iloc[500].Descripcion
# Out:
# 'Departamento en la colonia Napolescon 1cuartos y 0plazas de estacionamiento'

# %%
datos['Tiene_suite'] = datos['Suites'].apply(lambda x: 'Si' if x>0 else 'No')
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                           Descrpcion  \
# ...

# %%
datos.to_csv('inmuebles_dev', index=False, sep=';')
